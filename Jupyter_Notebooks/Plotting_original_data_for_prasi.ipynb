# %%
import pandas as pd
import numpy as py
import matplotlib.pyplot as plt

# %%
df = pd.read_pickle("../data/final_combined_financial_data").set_index("date")

# %%
df = df.drop("day_of_week",1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-23-6fc1eb5a46af> in <module>
# ----> 1 df = df.drop("day_of_week",1)
#
# ~/anaconda3/envs/backpack_banana/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3995             level=level,
#    3996             inplace=inplace,
# -> 3997             errors=errors,
#    3998         )
#    3999
#
# ~/anaconda3/envs/backpack_banana/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
#    3938         if inplace:
#
# ...

# %%
df
# Out:
#             CAC_40_FR  DAX_30_GR  DOW_JONES_US   FTSE_IT  IBEX_SP  NASDAQ_US  \
# date
# 2019-01-01        NaN        NaN           NaN       NaN      NaN        NaN
# 2019-01-02    4689.39   10580.19      23346.24  18330.99   8550.0   7263.870
# 2019-01-03    4611.49   10416.66      22686.22  18218.40   8523.3   7595.350
# 2019-01-04    4737.12   10767.69      23433.16  18831.79   8737.8   7828.910
# 2019-01-05        NaN        NaN           NaN       NaN      NaN   8049.641
# ...               ...        ...           ...       ...      ...        ...
# 2020-04-04        NaN        NaN           NaN       NaN      NaN        NaN
# 2020-04-05        NaN        NaN           NaN       NaN      NaN        NaN
# 2020-04-06    4346.14   10075.17      22679.99  17039.31   6844.3        NaN
# 2020-04-07    4438.27   10356.70      22653.86  17411.72   7002.0        NaN
# 2020-04-08        NaN        NaN           NaN       NaN      NaN        NaN
#
# ...

# %%
fig, ax = plt.subplots(figsize=(14,10))
ax.plot(df)
