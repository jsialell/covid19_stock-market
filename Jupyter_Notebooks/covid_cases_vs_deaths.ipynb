# %%
import pandas as pd

# %% [markdown]
# 1. Import of covid daily cases and covid daily deaths data

# %%
covid_cases = pd.read_csv("C:/Users/Admin/Documents/ironhack/ironhack-projects/Data_Thief_Project_Team_Wall-e/data/covid_focus_countries.csv")

# %%
covid_deaths = pd.read_csv("C:/Users/Admin/Documents/ironhack/ironhack-projects/Data_Thief_Project_Team_Wall-e/data/deaths_focus_countries.csv")

# %%
covid_cases
# Out:
#   Country/Region  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# 0          China      548      643      920     1406     2075     2877
# 1         France        0        0        2        3        3        3
# 2        Germany        0        0        0        0        0        1
# 3          Italy        0        0        0        0        0        0
# 4          Japan        2        2        2        2        4        4
# 5          Spain        0        0        0        0        0        0
# 6             US        1        1        2        2        5        5
#
#    1/28/20  1/29/20  1/30/20  ...  3/30/20  3/31/20  4/1/20  4/2/20  4/3/20  \
# 0     5509     6087     8141  ...    82198    82279   82361   82432   82511
# 1        4        5        5  ...    45170    52827   57749   59929   65202
# 2        4        4        4  ...    66885    71808   77872   84794   91159
# 3        0        0        0  ...   101739   105792  110574  115242  119827
# ...

# %%
covid_deaths
# Out:
#   Country/Region  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# 0          China       17       18       26       42       56       82
# 1         France        0        0        0        0        0        0
# 2        Germany        0        0        0        0        0        0
# 3          Italy        0        0        0        0        0        0
# 4          Japan        0        0        0        0        0        0
# 5          Spain        0        0        0        0        0        0
# 6             US        0        0        0        0        0        0
#
#    1/28/20  1/29/20  1/30/20  ...  3/30/20  3/31/20  4/1/20  4/2/20  4/3/20  \
# 0      131      133      171  ...     3308     3309    3316    3322    3326
# 1        0        0        0  ...     3030     3532    4043    5398    6520
# 2        0        0        0  ...      645      775     920    1107    1275
# 3        0        0        0  ...    11591    12428   13155   13915   14681
# ...

# %% [markdown]
# 2. Merging fo total deaths column with vodi daily cases data frame

# %%
covid_cases["Deaths"] = covid_deaths["Total"]

# %%
covid_cases
# Out:
#   Country/Region  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# 0          China      548      643      920     1406     2075     2877
# 1         France        0        0        2        3        3        3
# 2        Germany        0        0        0        0        0        1
# 3          Italy        0        0        0        0        0        0
# 4          Japan        2        2        2        2        4        4
# 5          Spain        0        0        0        0        0        0
# 6             US        1        1        2        2        5        5
#
#    1/28/20  1/29/20  1/30/20  ...  3/31/20  4/1/20  4/2/20  4/3/20  4/4/20  \
# 0     5509     6087     8141  ...    82279   82361   82432   82511   82543
# 1        4        5        5  ...    52827   57749   59929   65202   90848
# 2        4        4        4  ...    71808   77872   84794   91159   96092
# 3        0        0        0  ...   105792  110574  115242  119827  124632
# ...

# %% [markdown]
# 3. Creation of a dictionary with each ofcus country's population, in order to calculate the deaths per 1 million for each country

# %%
#https://www.worldometers.info/coronavirus/

# %%
population_dict = {"China": 1439323776,
                  "France" : 65273511,
                  "Germany" : 83783942,
                   "Italy" : 60461826,
                  "Japan" : 126476461,
                   "Spain" : 46754778,
                   "United States" : 331002651}

# %%
covid_cases["population"] = population_dict.values()

# %%
covid_cases
# Out:
#   Country/Region  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# 0          China      548      643      920     1406     2075     2877
# 1         France        0        0        2        3        3        3
# 2        Germany        0        0        0        0        0        1
# 3          Italy        0        0        0        0        0        0
# 4          Japan        2        2        2        2        4        4
# 5          Spain        0        0        0        0        0        0
# 6             US        1        1        2        2        5        5
#
#    1/28/20  1/29/20  1/30/20  ...  4/1/20  4/2/20  4/3/20  4/4/20  4/5/20  \
# 0     5509     6087     8141  ...   82361   82432   82511   82543   82602
# 1        4        5        5  ...   57749   59929   65202   90848   93773
# 2        4        4        4  ...   77872   84794   91159   96092  100123
# 3        0        0        0  ...  110574  115242  119827  124632  128948
# ...

# %%
covid_cases["deaths/1million"] = covid_cases["Deaths"] / (covid_cases["population"]/1000000)

# %%
covid_cases
# Out:
#   Country/Region  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# 0          China      548      643      920     1406     2075     2877
# 1         France        0        0        2        3        3        3
# 2        Germany        0        0        0        0        0        1
# 3          Italy        0        0        0        0        0        0
# 4          Japan        2        2        2        2        4        4
# 5          Spain        0        0        0        0        0        0
# 6             US        1        1        2        2        5        5
#
#    1/28/20  1/29/20  1/30/20  ...  4/2/20  4/3/20  4/4/20  4/5/20  4/6/20  \
# 0     5509     6087     8141  ...   82432   82511   82543   82602   82665
# 1        4        5        5  ...   59929   65202   90848   93773   98963
# 2        4        4        4  ...   84794   91159   96092  100123  103374
# 3        0        0        0  ...  115242  119827  124632  128948  132547
# ...

# %%
covid_cases.columns
# Out:
# Index(['Country/Region', '1/22/20', '1/23/20', '1/24/20', '1/25/20', '1/26/20',
#        '1/27/20', '1/28/20', '1/29/20', '1/30/20', '1/31/20', '2/1/20',
#        '2/2/20', '2/3/20', '2/4/20', '2/5/20', '2/6/20', '2/7/20', '2/8/20',
#        '2/9/20', '2/10/20', '2/11/20', '2/12/20', '2/13/20', '2/14/20',
#        '2/15/20', '2/16/20', '2/17/20', '2/18/20', '2/19/20', '2/20/20',
#        '2/21/20', '2/22/20', '2/23/20', '2/24/20', '2/25/20', '2/26/20',
#        '2/27/20', '2/28/20', '2/29/20', '3/1/20', '3/2/20', '3/3/20', '3/4/20',
#        '3/5/20', '3/6/20', '3/7/20', '3/8/20', '3/9/20', '3/10/20', '3/11/20',
#        '3/12/20', '3/13/20', '3/14/20', '3/15/20', '3/16/20', '3/17/20',
#        '3/18/20', '3/19/20', '3/20/20', '3/21/20', '3/22/20', '3/23/20',
#        '3/24/20', '3/25/20', '3/26/20', '3/27/20', '3/28/20', '3/29/20',
#        '3/30/20', '3/31/20', '4/1/20', '4/2/20', '4/3/20', '4/4/20', '4/5/20',
# ...

# %% [markdown]
# 4. renaming columns

# %%
covid_cases.columns = ['country', '1/22/20', '1/23/20', '1/24/20', '1/25/20', '1/26/20',
       '1/27/20', '1/28/20', '1/29/20', '1/30/20', '1/31/20', '2/1/20',
       '2/2/20', '2/3/20', '2/4/20', '2/5/20', '2/6/20', '2/7/20', '2/8/20',
       '2/9/20', '2/10/20', '2/11/20', '2/12/20', '2/13/20', '2/14/20',
       '2/15/20', '2/16/20', '2/17/20', '2/18/20', '2/19/20', '2/20/20',
       '2/21/20', '2/22/20', '2/23/20', '2/24/20', '2/25/20', '2/26/20',
       '2/27/20', '2/28/20', '2/29/20', '3/1/20', '3/2/20', '3/3/20', '3/4/20',
       '3/5/20', '3/6/20', '3/7/20', '3/8/20', '3/9/20', '3/10/20', '3/11/20',
       '3/12/20', '3/13/20', '3/14/20', '3/15/20', '3/16/20', '3/17/20',
       '3/18/20', '3/19/20', '3/20/20', '3/21/20', '3/22/20', '3/23/20',
       '3/24/20', '3/25/20', '3/26/20', '3/27/20', '3/28/20', '3/29/20',
       '3/30/20', '3/31/20', '4/1/20', '4/2/20', '4/3/20', '4/4/20', '4/5/20',
       '4/6/20', '4/7/20', 'total_infected', 'deaths', 'population', 'deaths/1million']

# %%
covid_cases
# Out:
#    country  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  \
# 0    China      548      643      920     1406     2075     2877     5509
# 1   France        0        0        2        3        3        3        4
# 2  Germany        0        0        0        0        0        1        4
# 3    Italy        0        0        0        0        0        0        0
# 4    Japan        2        2        2        2        4        4        7
# 5    Spain        0        0        0        0        0        0        0
# 6       US        1        1        2        2        5        5        5
#
#    1/29/20  1/30/20  ...  4/2/20  4/3/20  4/4/20  4/5/20  4/6/20  4/7/20  \
# 0     6087     8141  ...   82432   82511   82543   82602   82665   82718
# 1        5        5  ...   59929   65202   90848   93773   98963  110065
# 2        4        4  ...   84794   91159   96092  100123  103374  107663
# 3        0        0  ...  115242  119827  124632  128948  132547  135586
# ...

# %%
#covid_cases.to_csv("C:/Users/Admin/Documents/ironhack/ironhack-projects/Data_Thief_Project_Team_Wall-e/data/final_covid_data.csv", index=False)

# %% [markdown]
# 5. creating a summary data frame for the data with the msot important values (total infected, deaths, and deaths/1 million)

# %%
covid_clean = covid_cases[["country", "total_infected", "deaths", "deaths/1million" ]]

# %%
covid_clean
# Out:
#    country  total_infected  deaths  deaths/1million
# 0    China           82718    3335         2.317060
# 1   France          110065   10343       158.456315
# 2  Germany          107663    2016        24.061890
# 3    Italy          135586   17127       283.269645
# 4    Japan            3906      92         0.727408
# 5    Spain          141942   14045       300.397106
# 6       US          396223   12722        38.434737

# %%
#covid_clean.to_csv("C:/Users/Admin/Documents/ironhack/ironhack-projects/Data_Thief_Project_Team_Wall-e/data/final_covid_data_clean.csv", index=False)
